# %%
import numpy as np
# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit import *
# Loading your IBM Q account(s)
provider = IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2021-05-15 06:49:32,350: Credentials are already in use. The existing account in the session will be replaced.

# %%
backend = provider.get_backend('ibmq_belem')
plot_gate_map(backend) #Tells us the way the qubits are arranged in a quantum system

# %%
plot_error_map(backend) #Also tell us the error rate of the qubits

# %%
#THERE ARE 2 WAYS TO SEE THE VERSION OF QISKIT:-

# %%
qiskit.__qiskit_version__     #TELLS US ABOUT THE VERSION OF QISKIT
# Out:
# {'qiskit-terra': '0.17.1', 'qiskit-aer': '0.8.2', 'qiskit-ignis': '0.6.0', 'qiskit-ibmq-provider': '0.12.3', 'qiskit-aqua': '0.9.1', 'qiskit': '0.25.3', 'qiskit-nature': '0.1.1', 'qiskit-finance': None, 'qiskit-optimization': '0.1.0', 'qiskit-machine-learning': None}

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td>Qiskit</td><td>0.25.3</td></tr><tr><td>Terra</td><td>0.17.1</td></tr><tr><td>Aer</td><td>0.8.2</td></tr><tr><td>Ignis</td><td>0.6.0</td></tr><tr><td>Aqua</td><td>0.9.1</td></tr><tr><td>IBM Q Provider</td><td>0.12.3</td></tr><tr><th>System information</th></tr><tr><td>Python</td><td>3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27)
# [GCC 9.3.0]</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>8</td></tr><tr><td>Memory (Gb)</td><td>31.400047302246094</td></tr><tr><td colspan='2'>Sat May 15 06:50:47 2021 UTC</td></tr></table>

# %%
# %qiskit_backend_overview #TELLS US ABOUT THE HARDWARE PART OF EACH AVAILABLE QUANTUM SYSTEM.
# Out:
# VBox(children=(HTML(value="<h2 style ='color:#ffffff; background-color:#000000;padding-top: 1%; padding-bottom…

# %%
#T1 = RELAXATION TIME | T2 = DECOHERNECE TIME  | Avg. CX Err = Gate error rate | Avg. Meas.Er = Measurement error rate
